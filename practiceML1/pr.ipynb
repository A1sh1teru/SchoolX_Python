# %%
# %pip install -q seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('python_task_dataset.csv')

# %%
df.head()
# Out:
#    device_id device_type             datetime  ev_type adv_type  region_id  \
# 0     100001     android  2019-03-01 15:58:02        0    multi          2
# 1     100001     android  2019-03-01 17:13:53        0    multi          2
# 2     100002     android  2019-03-01 23:13:25        0    multi          2
# 3     100002     android  2019-03-01 23:25:06        0    multi          2
# 4     100003     android  2019-03-01 15:27:53        0    multi          1
#
#    age  gender
# 0   14       2
# 1   14       2
# 2    0       0
# 3    0       0
# 4    0       0

# %%
clicks_df = df[df['ev_type'] == 1]
user_clicks = clicks_df.groupby('device_id').size().reset_index(name='click_count')
print(user_clicks)
# Out:
#       device_id  click_count
# 0        100007            1
# 1        100020            1
# 2        100042            1
# 3        100193            1
# 4        100246            1
# ...         ...          ...
# 4037     286942            1
# 4038     286952            1
# 4039     286971            1
# 4040     287005            1
# 4041     287125            1
#
# [4042 rows x 2 columns]

# %%
sorted_user_clicks = user_clicks.sort_values(by='click_count', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=sorted_user_clicks.head(10), x='device_id', y='click_count')
plt.xlabel('device_id')
plt.ylabel('Количество кликов')
plt.title('Топ 10 пользователей с наибольшим количеством кликов')
plt.show()

# %%
# id_133643 = df['device_id[133643]']
df['device_id'].value(133643)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7620\1864477240.py in ?()
#       1 # id_133643 = df['device_id[133643]']
# ----> 2 df['device_id'].value(133643)
#
# c:\Users\velic\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
df.iloc [[177236]]
# Out:
#         device_id device_type             datetime  ev_type adv_type  \
# 177236     210075     android  2019-03-06 12:40:49        0    video
#
#         region_id  age  gender
# 177236          1   30       1
