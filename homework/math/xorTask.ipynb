# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
class XORModel(nn.Module):
    def __init__(self):
        super(XORModel, self).__init__()
        self.hidden = nn.Linear(2, 2) 
        self.output = nn.Linear(2, 1) 

    def forward(self, x):
        x = torch.sigmoid(self.hidden(x))
        x = torch.sigmoid(self.output(x))
        return x

model = XORModel()

criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

input_data = torch.tensor([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=torch.float32)
labels = torch.tensor([[0], [1], [1], [0]], dtype=torch.float32)

epochs = 1000
for epoch in range(epochs):
    optimizer.zero_grad()
    outputs = model(input_data)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch+1}/{epochs}")
    print(f"Loss: {loss.item()}")

test_data = torch.tensor([[0, 1], [1, 0]], dtype=torch.float32)
predictions = model(test_data)
rounded_predictions = torch.round(predictions)

print(rounded_predictions)
# Out:
# Epoch 1/1000
# Loss: 0.712504506111145
# Epoch 2/1000
# Loss: 0.7112787961959839
# Epoch 3/1000
# Loss: 0.710129976272583
# Epoch 4/1000
# Loss: 0.7090532183647156
# Epoch 5/1000
# Loss: 0.7080444097518921
# Epoch 6/1000
# Loss: 0.7070993185043335
# Epoch 7/1000
# Loss: 0.7062141299247742
# Epoch 8/1000
# Loss: 0.7053850889205933
# Epoch 9/1000
# Loss: 0.7046089172363281
# Epoch 10/1000
# Loss: 0.7038822770118713
# Epoch 11/1000
# Loss: 0.7032020688056946
# Epoch 12/1000
# Loss: 0.7025654315948486
# Epoch 13/1000
# Loss: 0.7019698023796082
# Epoch 14/1000
# Loss: 0.7014124393463135
# Epoch 15/1000
# Loss: 0.7008908987045288
# Epoch 16/1000
# Loss: 0.7004030346870422
# Epoch 17/1000
# Loss: 0.6999467611312866
# Epoch 18/1000
# Loss: 0.69951993227005
# Epoch 19/1000
# Loss: 0.6991207599639893
# Epoch 20/1000
# Loss: 0.6987475156784058
# Epoch 21/1000
# Loss: 0.6983985900878906
# Epoch 22/1000
# Loss: 0.6980723738670349
# Epoch 23/1000
# Loss: 0.6977673172950745
# Epoch 24/1000
# ...

# %% [markdown]
# ### Почему нужно использовать как минимум один скрытый слой?
#
# *Использование скрытого слоя позволяет нейронной сети выучить нелинейные связи между входными и выходными узлами. Скрытый слой содержит нейроны, которые могут представлять сложные нелинейные функции активации, такие как сигмоид, гиперболический тангенс или ReLU. Это позволяет нейронной сети разделить пространство входных данных и достичь точного предсказания XOR.*
